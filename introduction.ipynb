# %% [markdown]
# <a href="https://colab.research.google.com/github/angel3216167656/intro_python_202320/blob/main/introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduccion a python
# ## Curso de programacion y algoritmia UPB 202320
# - Nombre: Angel Bolaño
# - ID: 501080
# - Email: angel.bolano@upb.edu.co
#
# Esta es la expresion de la linea recta:
# $$y = mx + b$$
#
# donde $x$ es la posicion.
